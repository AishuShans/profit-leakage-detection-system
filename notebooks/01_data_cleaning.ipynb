# %% [markdown]
# data preprocessing and cleaning

# %% [markdown]
# 1. import required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2.load raw dataset

# %%
df = pd.read_csv("profit_leakage_large_dataset.csv")
df.head()
# Out:
#    order_id           order_date  customer_id customer_type region  \
# 0         1  2022-01-01 00:00:00        16795        Retail  North
# 1         2  2022-01-01 00:01:00         1860     Corporate  North
# 2         3  2022-01-01 00:02:00        39158     Wholesale   East
# 3         4  2022-01-01 00:03:00        45732        Retail  South
# 4         5  2022-01-01 00:04:00        12284        Retail  North
#
#   sales_channel  product_id product_category  unit_cost  unit_price  ...  \
# 0   Distributor         435       Automobile    4829.88      888.93  ...
# 1   Distributor         235           Pharma    3173.46     4089.16  ...
# 2        Online         729      Electronics    3498.54     3923.52  ...
# 3   Distributor        1939        Furniture     628.06      851.16  ...
# 4        Online        1670           Pharma    1257.04     3229.26  ...
#
#    refund_amount  inventory_level  reorder_level  holding_cost  \
# ...

# %% [markdown]
# 3.dataset shape

# %%
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# 4.dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               100000 non-null  int64
#  1   order_date             100000 non-null  object
#  2   customer_id            100000 non-null  int64
#  3   customer_type          100000 non-null  object
#  4   region                 100000 non-null  object
#  5   sales_channel          100000 non-null  object
#  6   product_id             100000 non-null  int64
#  7   product_category       100000 non-null  object
#  8   unit_cost              100000 non-null  float64
#  9   unit_price             100000 non-null  float64
#  10  quantity_sold          100000 non-null  int64
#  11  revenue                100000 non-null  float64
#  12  cost                   100000 non-null  float64
#  13  discount_percent       100000 non-null  float64
# ...

# %% [markdown]
# 5.statistical summary

# %%
df.describe()
# Out:
#             order_id    customer_id     product_id      unit_cost  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000   25425.890620    1048.824360    2528.185378
# std     28867.657797   14109.659287     548.905354    1426.069829
# min         1.000000    1000.000000     100.000000      50.020000
# 25%     25000.750000   13234.750000     574.000000    1295.332500
# 50%     50000.500000   25295.500000    1049.000000    2529.535000
# 75%     75000.250000   37612.250000    1524.000000    3761.725000
# max    100000.000000   49998.000000    1999.000000    4999.960000
#
#           unit_price  quantity_sold        revenue           cost  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean     4047.746859       9.998520   40414.145656   25277.563594
# std      2287.601470       5.476367   34183.022732   21319.626407
# min        80.050000       1.000000      83.810000      50.890000
# ...

# %% [markdown]
# 6.check missing values

# %%
df.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# customer_id              0
# customer_type            0
# region                   0
# sales_channel            0
# product_id               0
# product_category         0
# unit_cost                0
# unit_price               0
# quantity_sold            0
# revenue                  0
# cost                     0
# discount_percent         0
# discount_amount          0
# net_revenue              0
# profit                   0
# return_flag              0
# refund_amount            0
# inventory_level          0
# reorder_level            0
# holding_cost             0
# payment_delay_days       0
# outstanding_amount       0
# supplier_delay_days      0
# logistics_cost           0
# operational_cost         0
# profit_margin_percent    0
# dtype: int64

# %% [markdown]
# 7.check duplicate records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 8.datatype correction

# %%
df["order_date"] = pd.to_datetime(df["order_date"])

# %% [markdown]
# 9.business logic validation

# %%
df["profit_check"] = df["net_revenue"] - df["cost"]

# %%
(df["profit"] - df["profit_check"]).abs().mean()
# Out:
# np.float64(1.4333001951971625e-12)

# %% [markdown]
# 10.remove temporary column

# %%
df.drop(columns=["profit_check"], inplace=True)

# %% [markdown]
# 11.final dataset check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               100000 non-null  int64
#  1   order_date             100000 non-null  datetime64[ns]
#  2   customer_id            100000 non-null  int64
#  3   customer_type          100000 non-null  object
#  4   region                 100000 non-null  object
#  5   sales_channel          100000 non-null  object
#  6   product_id             100000 non-null  int64
#  7   product_category       100000 non-null  object
#  8   unit_cost              100000 non-null  float64
#  9   unit_price             100000 non-null  float64
#  10  quantity_sold          100000 non-null  int64
#  11  revenue                100000 non-null  float64
#  12  cost                   100000 non-null  float64
#  13  discount_percent       100000 non-null  float64
# ...

# %%
df.head()
# Out:
#    order_id          order_date  customer_id customer_type region  \
# 0         1 2022-01-01 00:00:00        16795        Retail  North
# 1         2 2022-01-01 00:01:00         1860     Corporate  North
# 2         3 2022-01-01 00:02:00        39158     Wholesale   East
# 3         4 2022-01-01 00:03:00        45732        Retail  South
# 4         5 2022-01-01 00:04:00        12284        Retail  North
#
#   sales_channel  product_id product_category  unit_cost  unit_price  ...  \
# 0   Distributor         435       Automobile    4829.88      888.93  ...
# 1   Distributor         235           Pharma    3173.46     4089.16  ...
# 2        Online         729      Electronics    3498.54     3923.52  ...
# 3   Distributor        1939        Furniture     628.06      851.16  ...
# 4        Online        1670           Pharma    1257.04     3229.26  ...
#
#    refund_amount  inventory_level  reorder_level  holding_cost  \
# ...

# %% [markdown]
# save cleaned dataset

# %%
df.to_csv("profit_leakage_cleaned.csv", index=False)
